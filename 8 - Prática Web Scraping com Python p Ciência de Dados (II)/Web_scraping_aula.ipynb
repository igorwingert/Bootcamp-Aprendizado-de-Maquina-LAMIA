# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
# carrega o conteudo da pagina e transforma em objeto beautifulsoup
r = requests.get("https://keithgalli.github.io/web-scraping/example.html")

soup = bs(r.content)

# mostra o html de forma organizada
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %%
first_header = soup.find("h2")

headers = soup.find_all("h2")
print(headers) # busca os elementos h2 dentro da pagina
# Out:
# [<h2>A Header</h2>, <h2>Another header</h2>]

# %%
first_header = soup.find(["h1", "h2"])

headers = soup.find_all(["h1", "h2"])
headers # busca mais de um tipo de tag ao mesmo tempo
# Out:
# [<h1>HTML Webpage</h1>, <h2>A Header</h2>, <h2>Another header</h2>]

# %%
paragraph = soup.find_all("p", attrs={"id": "paragraph-id"})
paragraph # filtra elementos usando atributos da tag
# Out:
# [<p id="paragraph-id"><b>Some bold text</b></p>]

# %%
body = soup.find('body')
body # separa o corpo da pagina para fazer buscas dentro dele
# Out:
# <body>
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>
# <h2>A Header</h2>
# <p><i>Some italicized text</i></p>
# <h2>Another header</h2>
# <p id="paragraph-id"><b>Some bold text</b></p>
# </body>

# %%
body = soup.find('body')
div = body.find('div')
header = div.find('h1')
header # busca elementos dentro de outros elementos ja encontrados
# Out:
# <h1>HTML Webpage</h1>

# %%
print(soup.prettify()) # mostra o html completo para facilitar a busca de textos
# Out:
# <html>
#  <head>
#   <title>
#    HTML Example
#   </title>
#  </head>
#  <body>
#   <div align="middle">
#    <h1>
#     HTML Webpage
#    </h1>
#    <p>
#     Link to more interesting example:
#     <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#      keithgalli.github.io/web-scraping/webpage.html
#     </a>
#    </p>
#   </div>
#   <h2>
#    A Header
#   </h2>
#   <p>
#    <i>
#     Some italicized text
#    </i>
#   </p>
#   <h2>
#    Another header
#   </h2>
#   <p id="paragraph-id">
#    <b>
#     Some bold text
#    </b>
#   </p>
#  </body>
# </html>

# %%
paragraphs = soup.find_all("p", string="Some bold text")
paragraphs # busca paragrafos que tenham um texto especifico
# Out:
# [<p id="paragraph-id"><b>Some bold text</b></p>]

# %%
import re

paragraphs = soup.find_all("p", string=re.compile("Some"))
paragraphs

headers = soup.find_all("h2", string=re.compile("(H|h)eader"))
headers # usa regex para buscar textos que seguem um padrao
# Out:
# [<h2>A Header</h2>, <h2>Another header</h2>]

# %%
print(soup.body.prettify()) # mostra o conteudo do body de forma organizada
# Out:
# <body>
#  <div align="middle">
#   <h1>
#    HTML Webpage
#   </h1>
#   <p>
#    Link to more interesting example:
#    <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#     keithgalli.github.io/web-scraping/webpage.html
#    </a>
#   </p>
#  </div>
#  <h2>
#   A Header
#  </h2>
#  <p>
#   <i>
#    Some italicized text
#   </i>
#  </p>
#  <h2>
#   Another header
#  </h2>
#  <p id="paragraph-id">
#   <b>
#    Some bold text
#   </b>
#  </p>
# </body>

# %%
content = soup.select("p") # seleciona todos os parágrafos
content
# Out:
# [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>,
#  <p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
content = soup.select("div p") # seleciona parágrafos dentro de uma div
content
# Out:
# [<p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>]

# %%
paragraphs = soup.select("h2 ~ p") # pega paragrafos irmãos depois de um h2
paragraphs
# Out:
# [<p><i>Some italicized text</i></p>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
bold_text = soup.select("p#paragraph-id b") # texto em negrito dentro de um paragrafo especifico
bold_text
# Out:
# [<b>Some bold text</b>]

# %%
paragraphs = soup.select("body > p")
print(paragraphs)

for paragraph in paragraphs:
    print(paragraph.select("i")) # percorre cada paragrafo encontrado e procura dentro dele a <i> que representa texto em italians
# Out:
# [<p><i>Some italicized text</i></p>, <p id="paragraph-id"><b>Some bold text</b></p>]
# [<i>Some italicized text</i>]
# []

# %%
soup.select("[align=middle]") # busca elementos usando um atributo especifico
# Out:
# [<div align="middle">
#  <h1>HTML Webpage</h1>
#  <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
#  </div>]

# %%
header = soup.find("h2")
header.string

div = soup.find("div")
print(div.prettify())
print(div.get_text()) # quando tem mais elementos filhos, get_text pega o texto interno
# Out:
# <div align="middle">
#  <h1>
#   HTML Webpage
#  </h1>
#  <p>
#   Link to more interesting example:
#   <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#    keithgalli.github.io/web-scraping/webpage.html
#   </a>
#  </p>
# </div>
#
#
# HTML Webpage
# Link to more interesting example: keithgalli.github.io/web-scraping/webpage.html

# %%
link = soup.find("a")
link['href']

paragraphs = soup.select("p#paragraph-id")
paragraphs[0]['id'] # pega atributos especificos de uma tag
# Out:
# 'paragraph-id'

# %%
soup
# Out:
# <html>
# <head>
# <title>HTML Example</title>
# </head>
# <body>
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>
# <h2>A Header</h2>
# <p><i>Some italicized text</i></p>
# <h2>Another header</h2>
# <p id="paragraph-id"><b>Some bold text</b></p>
# </body>
# </html>

# %%
soup.body.div.h1.string # acessa elementos seguindo o caminho das tags
# Out:
# 'HTML Webpage'

# %%
print(soup.body.prettify()) # mostra o conteudo do body de forma organizada
# Out:
# <body>
#  <div align="middle">
#   <h1>
#    HTML Webpage
#   </h1>
#   <p>
#    Link to more interesting example:
#    <a href="https://keithgalli.github.io/web-scraping/webpage.html">
#     keithgalli.github.io/web-scraping/webpage.html
#    </a>
#   </p>
#  </div>
#  <h2>
#   A Header
#  </h2>
#  <p>
#   <i>
#    Some italicized text
#   </i>
#  </p>
#  <h2>
#   Another header
#  </h2>
#  <p id="paragraph-id">
#   <b>
#    Some bold text
#   </b>
#  </p>
# </body>

# %%
soup.body.find("div") # busca a div dentro do body
# Out:
# <div align="middle">
# <h1>HTML Webpage</h1>
# <p>Link to more interesting example: <a href="https://keithgalli.github.io/web-scraping/webpage.html">keithgalli.github.io/web-scraping/webpage.html</a></p>
# </div>

# %%
soup.body.find("div").find_next_siblings() # busca os elementos irmaos que aparecem depois da div
# Out:
# [<h2>A Header</h2>,
#  <p><i>Some italicized text</i></p>,
#  <h2>Another header</h2>,
#  <p id="paragraph-id"><b>Some bold text</b></p>]

# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
# carrega a pagina principal do exercicio
r = requests.get("https://keithgalli.github.io/web-scraping/webpage.html")

webpage = bs(r.content)

print(webpage.prettify()) # mostra o html de forma organizada
# Out:
# <html>
#  <head>
#   <title>
#    Keith Galli's Page
#   </title>
#   <style>
#    table {
#     border-collapse: collapse;
#   }
#   th {
#     padding:5px;
#   }
#   td {
#     border: 1px solid #ddd;
#     padding: 5px;
#   }
#   tr:nth-child(even) {
#     background-color: #f2f2f2;
#   }
#   th {
#     padding-top: 12px;
#     padding-bottom: 12px;
#     text-align: left;
#     background-color: #add8e6;
#     color: black;
#   }
#   .block {
#   width: 100px;
#   /*float: left;*/
#     display: inline-block;
#     zoom: 1;
#   }
#   .column {
#   float: left;
#   height: 200px;
#   /*width: 33.33%;*/
#   padding: 5px;
#   }
#
#   .row::after {
#     content: "";
#     clear: both;
#     display: table;
#   }
#   </style>
#  </head>
#  <body>
#   <h1>
#    Welcome to my page!
#   </h1>
#   <img src="./images/selfie1.jpg" width="300px"/>
#   <h2>
#    About me
#   </h2>
#   <p>
# ...

# %%
links = webpage.select("ul.socials a")
actual_links = [link['href'] for link in links]
actual_links # primeira forma de buscar os links das redes sociais
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
ulist = webpage.find("ul", attrs={"class": "socials"})
links = ulist.find_all("a")
actual_links = [link['href'] for link in links]
actual_links # segunda forma de buscar os links das redes sociais
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
links = webpage.select("li.social a")
actual_links = [link['href'] for link in links]
actual_links # terceira forma de buscar os links das redes sociais
# Out:
# ['https://www.instagram.com/keithgalli/',
#  'https://twitter.com/keithgalli',
#  'https://www.linkedin.com/in/keithgalli/',
#  'https://www.tiktok.com/@keithgalli']

# %%
import pandas as pd

table = webpage.select("table.hockey-stats")[0]
columns = table.find("thead").find_all("th")
column_names = [c.string for c in columns]

table_rows = table.find("tbody").find_all("tr")
l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [str(tr.get_text()).strip() for tr in td]
    l.append(row)

# cria um dataframe com os dados da tabela
df = pd.DataFrame(l, columns=column_names)
df.head()
# Out:
#          S                        Team    League  GP  G   A  TP PIM +/-     \
# 0  2014-15  MIT (Mass. Inst. of Tech.)   ACHA II  17  3   9  12  20      |
# 1  2015-16  MIT (Mass. Inst. of Tech.)   ACHA II   9  1   1   2   2      |
# 2  2016-17  MIT (Mass. Inst. of Tech.)   ACHA II  12  5   5  10   8   0  |
# 3  2017-18                Did not play                                   |
# 4  2018-19  MIT (Mass. Inst. of Tech.)  ACHA III   8  5  10  15   8      |
#
#   POST GP G A TP PIM +/-
# 0
# 1
# 2
# 3
# 4

# %%
import re

facts = webpage.select("ul.fun-facts li")
facts_with_is = [fact.find(string=re.compile("is")) for fact in facts]
facts_with_is = [fact.find_parent().get_text() for fact in facts_with_is if fact]
facts_with_is # seleciona os itens da lista de curiosidades
# Out:
# ['Middle name is Ronald',
#  'Dunkin Donuts coffee is better than Starbucks',
#  "A favorite book series of mine is Ender's Game",
#  'Current video game of choice is Rocket League',
#  "The band that I've seen the most times live is the Zac Brown Band"]

# %%
import re

facts = webpage.select("ul.fun-facts li")
facts_with_is = [fact.find(string=re.compile("is")) for fact in facts]
facts_with_is = [fact.find_parent().get_text() for fact in facts_with_is if fact]
facts_with_is # seleciona os itens da lista de curiosidades
# Out:
# ['Middle name is Ronald',
#  'Dunkin Donuts coffee is better than Starbucks',
#  "A favorite book series of mine is Ender's Game",
#  'Current video game of choice is Rocket League',
#  "The band that I've seen the most times live is the Zac Brown Band"]

# %%
files = webpage.select("div.block a")
files # busca os links dos arquivos do desafio
# Out:
# [<a href="challenge/file_1.html">File 1</a>,
#  <a href="challenge/file_2.html">File 2</a>,
#  <a href="challenge/file_3.html">File 3</a>,
#  <a href="challenge/file_4.html">File 4</a>,
#  <a href="challenge/file_5.html">File 5</a>,
#  <a href="challenge/file_6.html">File 6</a>,
#  <a href="challenge/file_7.html">File 7</a>,
#  <a href="challenge/file_8.html">File 8</a>,
#  <a href="challenge/file_9.html">File 9</a>,
#  <a href="challenge/file_10.html">File 10</a>]

# %%
files = webpage.select("div.block a")
relative_files = [f['href'] for f in files]
relative_files # pega apenas o caminho de cada arquivo
# Out:
# ['challenge/file_1.html',
#  'challenge/file_2.html',
#  'challenge/file_3.html',
#  'challenge/file_4.html',
#  'challenge/file_5.html',
#  'challenge/file_6.html',
#  'challenge/file_7.html',
#  'challenge/file_8.html',
#  'challenge/file_9.html',
#  'challenge/file_10.html']

# %%
url = "https://keithgalli.github.io/web-scraping/"
for f in relative_files:
    full_url = url + f
    page = requests.get(full_url)
    bs_page = bs(page.content)
    secret_word_element = bs_page.find("p", attrs={"id": "secret-word"})
    secret_word = secret_word_element.string
    print(secret_word) # acessa cada arquivo e pega a palavra secreta
# Out:
# Make
# sure
# to
# smash
# that
# like
# button
# and
# subscribe
# !!!
