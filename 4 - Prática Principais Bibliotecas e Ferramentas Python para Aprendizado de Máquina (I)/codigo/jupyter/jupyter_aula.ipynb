# %%
print("hello!") #testando comandos basicos no jupyter
# Out:
# hello!

# %%
1+1
# Out:
# 2

# %%
a = 1
print (a)
# Out:
# 1

# %%
print("hello")
# Out:
# hello

# %%
print(a)
# Out:
# 1

# %% [markdown]
# a linha vai printar algum texto

# %%
print("oi")
# Out:
# oi
