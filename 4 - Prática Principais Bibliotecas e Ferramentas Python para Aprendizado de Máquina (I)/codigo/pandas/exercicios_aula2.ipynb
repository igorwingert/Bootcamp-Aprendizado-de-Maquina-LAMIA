# %%
import pandas as pd

# %% [markdown]
# EX.2 E-COMMERCE

# %%
#le o arquivo ecommerce purchases

# %%
ecom = pd.read_csv('Ecommerce Purchases.txt')

# %%
ecom.head()#ve o head
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\nAlexisborough, NE 77...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\nSouth John, TN 8...  28 rn       PM
# 2                   Unit 0065 Box 5052\nDPO AP 27450  94 vE       PM
# 3              7780 Julia Fords\nNew Stacy, WA 45798  36 vm       PM
# 4  23012 Munoz Drive Suite 337\nNew Cynthia, TX 5...  20 IE       AM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 2  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_8_0 ...
# 4  Opera/9.58.(X11; Linux x86_64; it-IT) Presto/2...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
# ...

# %%
ecom.shape#linhas e colunas
# Out:
# (10000, 14)

# %%
ecom['Purchase Price'].mean()#preco de compra medio
# Out:
# np.float64(50.347302)

# %%
ecom['Purchase Price'].max()#preço de compra mais alto e mais baixo
# Out:
# np.float64(99.99)

# %%
ecom['Purchase Price'].min()
# Out:
# np.float64(0.0)

# %%
ecom[ecom['Language'] == 'en'].shape #"en" como lingua de escolha
# Out:
# (1098, 14)

# %%
ecom.columns #quantos tem o cargo de advogado

# %%
ecom[ecom['Job'] == 'Lawyer'].shape
# Out:
# (30, 14)

# %%
ecom['AM or PM'].value_counts()#quantas fizeram compras durante am e quantas pm
# Out:
# AM or PM
# PM    5068
# AM    4932
# Name: count, dtype: int64

# %%
ecom['Job'].value_counts().head() #5 titulos de trabalho mais comuns
# Out:
# Job
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Designer, jewellery              27
# Purchasing manager               27
# Name: count, dtype: int64

# %%
ecom['Job']
# Out:
# 0       Scientist, product/process development
# 1                            Drilling engineer
# 2                     Customer service manager
# 3                            Drilling engineer
# 4                                  Fine artist
#                          ...
# 9995                                Printmaker
# 9996                           Energy engineer
# 9997                        Veterinary surgeon
# 9998                  Local government officer
# 9999                    Embryologist, clinical
# Name: Job, Length: 10000, dtype: str

# %%
ecom[ecom['Lot'] == '90 WT']['Purchase Price']#preço da compra da transação do Lot:90WT
# Out:
# 513    75.1
# Name: Purchase Price, dtype: float64

# %%
ecom[ecom['Credit Card']==4926535242672853]['Email'] #email da pessoa com numero de credito: 4926535242672853
# Out:
# 1234    bondellen@williams-garza.com
# Name: Email, dtype: str

# %%
ecom[(ecom['CC Provider'] == 'American Express') & (ecom['Purchase Price'] > 95)].shape # quantas pessoas tem o american express como fornecedor E fizeram compras acima de $95,00?
# Out:
# (39, 14)

# %%
sum(ecom['CC Exp Date'].apply(lambda year : year[3:]) == '25') #pessoas com credit card q expira em 2025
# Out:
# 1033

# %%
ecom['Email'].apply(lambda prov: prov.split('@')[1]).value_counts().iloc[:5] # 5 principais provedores de email
# Out:
# Email
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: count, dtype: int64
