# %% [markdown]
# # Exemplo do Kaggle
#
# teste
# kaggle

# %%
print('teste teste')
# Out:
# teste teste

# %% [markdown]
# bonus do kaggle é que ele da acesso a todos os dataset publicos que eles disponibilizam

# %%
import pandas as pd

# %%
df = pd.read_csv('/kaggle/input/datasets/bobbyscience/league-of-legends-diamond-ranked-games-10-min/high_diamond_ranked_10min.csv')

# %%
df.head()
# Out:
#        gameId  blueWins  blueWardsPlaced  blueWardsDestroyed  blueFirstBlood  \
# 0  4519157822         0               28                   2               1
# 1  4523371949         0               12                   1               0
# 2  4521474530         0               15                   0               0
# 3  4524384067         0               43                   1               0
# 4  4436033771         0               75                   4               0
#
#    blueKills  blueDeaths  blueAssists  blueEliteMonsters  blueDragons  ...  \
# 0          9           6           11                  0            0  ...
# 1          5           5            5                  0            0  ...
# 2          7          11            4                  1            1  ...
# 3          4           5            5                  1            0  ...
# 4          6           6            6                  0            0  ...
#
# ...

# %%
df.plot(x='redGoldDiff', y='redExperienceDiff', kind='scatter', title='gold x xp') # não achei o dataset do professor
# Out:
# <Axes: title={'center': 'gold x xp'}, xlabel='redGoldDiff', ylabel='redExperienceDiff'>

# %% [markdown]
# https://www.kaggle.com/code/igorgabrielwingert/kaggle-aula (está publico)
